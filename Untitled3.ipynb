# %%
# !git clone https://github.com/alaneizyyasmeen-beep/Image-project
# Out:
# Cloning into 'Image-project'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 1.41 MiB | 30.00 MiB/s, done.

# %%
# Import necessary libraries
import cv2
import matplotlib.pyplot as plt
import os # Import the os module for directory operations

# Load the image
image_path = 'Image-project/flowers.jpg'

# --- Debugging step: List contents of the Image-project directory ---
print(f"Contents of '{os.path.dirname(image_path)}':")
try:
    for item in os.listdir(os.path.dirname(image_path)):
        print(f"  - {item}")
except FileNotFoundError:
    print(f"Error: Directory '{os.path.dirname(image_path)}' not found.")
# ------------------------------------------------------------------

image = cv2.imread(image_path)

# Check if image was loaded successfully
if image is None:
    print(f"Error: Could not load image from {image_path}. Please ensure the file exists and the path is correct.")
else:
    # Display the original image
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.show()

    # Rotate the image
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    angle = 45  # Rotate the image by 45 degrees
    scale = 1.0

    # Create the rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, scale)
    # Perform the rotation
    rotated_image = cv2.warpAffine(image, M, (w, h))

    # Display the rotated image
    plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
    plt.title('Rotated Image')
    plt.show()
# Out:
# Contents of 'Image-project':
#   - Github_code.zip
#   - .git
#   - .ipynb_checkpoints
#   - flowers.jpg
